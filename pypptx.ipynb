# %% [markdown]
# <a href="https://colab.research.google.com/github/yo-itz/pptx-template/blob/init/pypptx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-pptx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 11.7 MB/s eta 0:00:00
# ...

# %%
import pptx

# %%
from pptx import Presentation

# プレゼンテーションを作成
prs = Presentation('')

# タイトルスライドを追加
title_slide_layout = prs.slide_layouts[0]
slide = prs.slides.add_slide(title_slide_layout)
title = slide.shapes.title
subtitle = slide.placeholders[1]
title.text = "レポート"
subtitle.text = "name"


# タイトルスライドを追加
title_slide_layout = prs.slide_layouts[0]
slide = prs.slides.add_slide(title_slide_layout)
title = slide.shapes.title
subtitle = slide.placeholders[1]


# スライドを保存
prs.save('my_presentation.pptx')

# %%
from google.colab import files
files.download('my_presentation.pptx')
